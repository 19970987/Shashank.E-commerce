# %% [markdown]
# # PROJECT 1

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup

# %%
link = "https://www.ebay.com/itm/134638042371?_trkparms=pageci%3Acd839362-65cc-11ee-97da-8aa74efc965f%7Cparentrq%3A0f052b2b18b0acf322cec22dfffed4fc%7Ciid%3A1&var=434175605789"

# %%
response= urlopen(link)   # it helps to open a link

# %%
html_data=response.read() # it helps to read the link data

# %%
soup_data = soup(html_data)  # it helps to convert into beautifulsoup

# %%
soup_data.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>\n  <link href="//vi.vipr.ebaydesc.com" rel="dns-prefetch"/>\n  <link href="//p.ebaystatic.com" rel="dns-prefetch"/>\n  <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>\n  <link href="//q.ebaystatic.com" rel="dns-prefetch"/>\n  <link href="//pics.ebaystatic.com" rel="dns-prefetch"/>\n  <link href="//srx.main.ebayrtm.com" rel="dns-prefetch"/>\n  <link href="//reco.ebay.com" rel="dns-prefetch"/>\n  <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>\n  <link href="//secureir.ebaystatic.com" rel="dns-prefetch"/>\n  <link href="//i.ebayimg.com" rel="dns-prefetch"/>\n  <link href="//rover.ebay.com" rel="dns-prefetch"/>\n  <script>\n   $ssgST=new Date().getTime();\n  </script>\n  <style>\n   .font-marketsans body {\n        font-family: "Market Sans", Arial, sans-serif;\n    }\n  </style>\n  <script>\n   (function() {\n        var useCustomFont = (\'fontDisplay\' in document.documentElement.style) ||\n                        (localStorage && localStorage.getItem(\'ebay-font\'));\n        if (useCustomFont) {\n            document.documentElement.classList.add(\'font-marketsans\');\n        }\n    })();\n  </script>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <meta content="main" name="layout"/>\n  <meta content="unsafe-url" name="referrer">\n   <meta content="Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3&amp;#034; 8GB 256GB SSD  | eBay" property="og:title">\n    <meta content="34E98E6F27109BE1A9DCF19658EEEE33" name="msvalidate.01">\n     <link href="https://ir.ebaystatic.com" rel="preconnect">\n      <meta content="@eBay" name="twitter:site"/>\n      <meta content="Apple Macbook Pro Mneh3ll/a 2022 M2 8gb 13.3 256gb Ssd. Storage: 256GB. Model: Macbook Pro Mneh3ll/a 2022 Usb-c-67w. Storage type: SSD. Processor: M2. WARRANTY : 1 YEAR. This is necessary to keep your right to file a claim." property="og:description"/>\n      <meta content="ebay-objects:item" property="og:type"/>\n      <link href="https://www.ebay.com/itm/134638042371?_ul=IN" rel="canonical">\n       <meta content="max-snippet:-1, max-image-preview:large" name="robots"/>\n       <meta content="8kHr3jd3Z43q1ovwo0KVgo_NZKIEMjthBxti8m8fYTg" name="google-site-verification"/>\n       <meta content="en-US" http-equiv="content-language"/>\n       <meta content="eBay" property="og:site_name"/>\n       <meta content="6e11485a66d91eff" name="yandex-verification"/>\n       <meta content="acf32e2a69cbc2b0" name="y_key"/>\n       <link href="android-app://com.ebay.mobile/ebay/link/?nav=item.view&amp;id=134638042371&amp;referrer=http%3A%2F%2Frover.ebay.com%2Froverns%2F1%2F711-13271-9788-0%3Fmpcl%3Dhttp%253A%252F%252Fwww.ebay.com%252Fitm%252F134638042371" rel="alternate">\n        <link href="https://i.ebayimg.com" rel="preconnect">\n         <meta content="102628213125203" property="fb:app_id"/>\n         <title>\n          Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3&amp;#034; 8GB 256GB SSD  | eBay\n         </title>\n         <meta content="Apple Macbook Pro Mneh3ll/a 2022 M2 8gb 13.3 256gb Ssd. Storage: 256GB. Model: Macbook Pro Mneh3ll/a 2022 Usb-c-67w. Storage type: SSD. Processor: M2. WARRANTY : 1 YEAR. This is necessary to keep your right to file a claim." name="description"/>\n         <meta content="https://i.ebayimg.com/images/g/e90AAOSwXtplVNFb/s-l400.jpg" property="og:image"/>\n         <meta content="summary" name="twitter:card"/>\n         <meta content="Apple Macbook Pro Mneh3ll/a 2022 M2 8gb 13.3 256gb Ssd. Storage: 256GB. Model: Macbook Pro Mneh3ll/a 2022 Usb-c-67w. Storage type: SSD. Processor: M2. WARRANTY : 1 YEAR. This is necessary to keep your right to file a claim." name="twitter:description"/>\n         <meta content="https://www.ebay.com/itm/134638042371?_ul=IN" property="og:url"/>\n         <meta content="Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chi ...

# %%
soup_data
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/><link href="//vi.vipr.ebaydesc.com" rel="dns-prefetch"/><link href="//p.ebaystatic.com" rel="dns-prefetch"/><link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/><link href="//q.ebaystatic.com" rel="dns-prefetch"/><link href="//pics.ebaystatic.com" rel="dns-prefetch"/><link href="//srx.main.ebayrtm.com" rel="dns-prefetch"/><link href="//reco.ebay.com" rel="dns-prefetch"/><link href="//ir.ebaystatic.com" rel="dns-prefetch"/><link href="//secureir.ebaystatic.com" rel="dns-prefetch"/><link href="//i.ebayimg.com" rel="dns-prefetch"/><link href="//rover.ebay.com" rel="dns-prefetch"/><script>$ssgST=new Date().getTime();</script><style>
#     .font-marketsans body {
#         font-family: "Market Sans", Arial, sans-serif;
#     }
# </style><script>
#     (function() {
#         var useCustomFont = ('fontDisplay' in document.documentElement.style) ||
#                         (localStorage && localStorage.getItem('ebay-font'));
#         if (useCustomFont) {
#             document.documentElement.classList.add('font-marketsans');
#         }
#     })();
# </script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="main" name="layout"/><meta content="unsafe-url" name="referrer"><meta content="Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3&amp;#034; 8GB 256GB SSD  | eBay" property="og:title"><meta content="34E98E6F27109BE1A9DCF19658EEEE33" name="msvalidate.01"><link href="https://ir.ebaystatic.com" rel="preconnect"><meta content="@eBay" name="twitter:site"/><meta content="Apple Macbook Pro Mneh3ll/a 2022 M2 8gb 13.3 256gb Ssd. Storage: 256GB. Model: Macbook Pro Mneh3ll/a 2022 Usb-c-67w. Storage type: SSD. Processor: M2. WARRANTY : 1 YEAR. This is necessary to keep your right to file a claim." property="og:description"/><meta content="ebay-objects:item" property="og:type"/><link href="https://www.ebay.com/itm/134638042371?_ul=IN" rel="canonical"><meta content="max-snippet:-1, max-image-preview:large" name="robots"/><meta content="8kHr3jd3Z43q1ovwo0KVgo_NZKIEMjthBxti8m8fYTg" name="google-site-verification"/><meta content="en-US" http-equiv="content-language"/><meta content="eBay" property="og:site_name"/><meta content="6e11485a66d91eff" name="yandex-verification"/><meta content="acf32e2a69cbc2b0" name="y_key"/><link href="android-app://com.ebay.mobile/ebay/link/?nav=item.view&amp;id=134638042371&amp;referrer=http%3A%2F%2Frover.ebay.com%2Froverns%2F1%2F711-13271-9788-0%3Fmpcl%3Dhttp%253A%252F%252Fwww.ebay.com%252Fitm%252F134638042371" rel="alternate"><link href="https://i.ebayimg.com" rel="preconnect"><meta content="102628213125203" property="fb:app_id"/><title>Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3&amp;#034; 8GB 256GB SSD  | eBay</title><meta content="Apple Macbook Pro Mneh3ll/a 2022 M2 8gb 13.3 256gb Ssd. Storage: 256GB. Model: Macbook Pro Mneh3ll/a 2022 Usb-c-67w. Storage type: SSD. Processor: M2. WARRANTY : 1 YEAR. This is necessary to keep your right to file a claim." name="description"/><meta content="https://i.ebayimg.com/images/g/e90AAOSwXtplVNFb/s-l400.jpg" property="og:image"/><meta content="summary" name="twitter:card"/><meta content="Apple Macbook Pro Mneh3ll/a 2022 M2 8gb 13.3 256gb Ssd. Storage: 256GB. Model: Macbook Pro Mneh3ll/a 2022 Usb-c-67w. Storage type: SSD. Processor: M2. WARRANTY : 1 YEAR. This is necessary to keep your right to file a claim." name="twitter:description"/><meta content="https://www.ebay.com/itm/134638042371?_ul=IN" property="og:url"/><meta content="Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3&amp;#034; 8GB 256GB SSD" name="twitter:title"/><meta content="https://i.ebayimg.com/images/g/e90AAOSwXtplVNFb/s-l400.jpg" name="twitter:image"/><!-- NGMARS SIGNATURE --><link href="https://www.ebay.com/itm/134638042371" hreflang="en-US" rel="alternate"><link href="https://www.ebay.ch/itm/134638042371" hreflang="de-CH" rel="alternate"><link href="https://www.ebay.ca/itm/134638042371" hreflang="en-CA" rel="alternate"><link href="https://www.ebay.fr/itm/134638042371" hreflang="fr-FR" rel="alternate"><link href="https://www.ebay.com/itm/134638042371?_ul=MX" hreflang="es-MX" rel="alternate"><link href="https://www.ebay.com/itm/134638042371?_ul=AR" hreflang="es-AR" rel="alternate"><link href="https://www.ebay.de/itm/134638042371" hreflang="de-DE" rel="alternate"><link href="https://www.ebay.ie/itm/134638042371" hreflang="en-IE" rel="alternate"><link href="https://www.ebay.com.au/itm/134638042371" hreflang="en-AU" rel="alternate"/><link href="https://www.ebay.com.my/itm/134638042371" hreflang="en-MY" rel="alternate"/><link href="https://www.ebay.at/itm/134638042371" hreflang="de-AT" rel="alternate"/><link href="https://www.ebay.nl/itm/134638042371" hreflang="nl-NL" rel="alternate"/><link href="https://www.cafr.ebay.ca/itm/134638042371" hreflang="fr-CA" rel="alternate"/><link href="https://www.ebay.ph/itm/134638042371" hreflang="en-PH" rel="alternate"/><link href="https://www.ebay.pl/itm/134638042371" hreflang="pl-PL" rel="alternate"/><link href= ...
# <link href="https://ir.ebaystatic.com/rs/c/inception-n4N4YOSN.css" rel="stylesheet"/></link></link></link></link></link></link></link></link></link></link></link></link></meta></meta></meta></head><body class="vi-body en-US"><div class="sz940 sz1280"><div class="top-panel-container"><header class="vi-global-header" id="vi-global-header"><script type="text/javascript">var GHpre = {userAuth:false,si:false}</script><style>.gh-hide-if-nocss{display:none;}.gh-ar-hdn{color:#fff}</style> <div class="gh-acc-exp-div gh-hide-if-nocss"><a class="gh-acc-a" href="#mainContent" id="gh-hdn-stm">Skip to main content</a></div><!--[if lt IE 9]><div id="gh" role="banner" class="gh-IE8 gh-flex gh-pre-js gh-w "><![endif]--><header class="gh-ui-6-5 gh-flex gh-pre-js gh-w gh-sch-prom" data-treatment="" id="gh" role="banner"><table class="gh-tbl" role="presentation"><tbody><tr><td class="gh-td"><a _sp="m570.l2586" href="https://www.ebay.com/" id="gh-la"><img alt="eBay Home" height="200" id="gh-logo" src="https://ir.ebaystatic.com/rs/v/fxxj3ttftm5ltcqnto1o4baovyl.png" style="clip:rect(47px, 118px, 95px, 0px); position:absolute; top:-47px;left:0" width="250"/></a></td><td class="gh-td"><div class="gh-hide-if-nocss" id="gh-shop"><button aria-controls="gh-sbc-o" aria-expanded="false" class="gh-control" id="gh-shop-a"> Shop by category<i class="gh-sprRetina" id="gh-shop-ei"></i></button><div id="gh-sbc-o"><h2 class="gh-ar-hdn">Shop by category</h2></div></div></td><td class="gh-td-s"><form action="https://www.ebay.com/sch/i.html" id="gh-f" method="get"><input name="_from" type="hidden" value="R40"/><input name="_trksid" type="hidden" value="m570.l1313"/><table class="gh-tbl2" role="presentation"><tbody><tr><td class="gh-td-s"><div id="gh-ac-box"><div id="gh-ac-box2"><label class="gh-ar-hdn" for="gh-ac">Enter your search keyword</label><input aria-autocomplete="list" aria-expanded="false" aria-label="Search for anything" autocapitalize="off" autocomplete="off" autocorrect="off" class="gh-tb ui-autocomplete-input" id="gh-ac" maxlength="300" name="_nkw" placeholder="Search for anything" size="50" spellcheck="false" type="text"/><input style="display:none"/><script> if(document.getElementById('gh-ac').value.length !== 0) { document.getElementById('gh-ac-box').classList.add('gh-ac-box-focus'); document.getElementById('gh').classList.add('gh-sch-focus'); } </script><svg aria-hidden="true" class="icon icon--search gh-search__icon" focusable="false" height="14" width="14"><use xlink:href="#icon-search"></use></svg> </div></div></td><td class="gh-td" id="gh-cat-td"><div id="gh-cat-box"><select aria-label="Select a category for search" class="gh-sb" id="gh-cat" name="_sacat" size="1"><option value="0">All Categories</option></select></div></td><td class="gh-td gh-sch-btn"><input class="btn btn-ter gh-spr" id="gh-btn" type="submit" value="Search"/><svg aria-hidden="true" class="icon icon--search gh-search-btn__icon" focusable="false" height="22" width="22"><use xlink:href="#icon-search"></use></svg></td><td class="gh-td" id="gh-as-td"><a _sp="m570.l2614" aria-label="Advanced Search" href="https://www.ebay.com/sch/ebayadvsearch" id="gh-as-a" title="Advanced Search">Advanced</a></td></tr></tbody></table></form></td><td class="sticky_placeholder"><ul></ul></td></tr></tbody></table><div aria-label="Account" class="gh-hide-if-nocss" id="gh-top" role="navigation"><ul id="gh-topl"><li class="gh-t" id="gh-eb-u"><noscript class="gh-t gh-spr">Hi (<a href="https://signin.ebay.com/ws/eBayISAPI.dll?SignIn&amp;_trksid=m570.l3348">Sign in</a> to bid or buy)</noscript><script> var supressUserGreeting = false; (function(){try{ var sup = !!(supressUserGreeting && typeof window.GHpre !== 'undefined' && !window.GHpre.si); var d=document.cookie,a=((a=d.match(/u1f[^a-zA-Z0-9]([^^]*)[0-9a-z]{8}/))?a[1].replace(/\+/g," "):"").replace(/(.{12}).*/,"$1...");if(/[<>%&'\/]/.test(a)){throw(1)}document.write("<span id=gh-ug"+(!a||/u1p.QEBfX/.test(d)?' class=gh-ug-guest>Hi! <a href="https://signin ...
#                 {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"eBay","item":"https://www.ebay.com"},{"@type":"ListItem","position":2,"name":"Electronics","item":"https://www.ebay.com/b/Electronics/bn_7000259124"},{"@type":"ListItem","position":3,"name":"Computers/Tablets & Networking","item":"https://www.ebay.com/b/Computers-Tablets-Network-Hardware/58058/bn_1865247"},{"@type":"ListItem","position":4,"name":"Laptops & Netbooks","item":"https://www.ebay.com/b/Laptops-Netbooks/175672/bn_1648276"},{"@type":"ListItem","position":5,"name":"Apple Laptops","item":"https://www.ebay.com/b/Apple-Laptops/111422/bn_320025"}]}
#             </script><script>
#     document.addEventListener("DOMContentLoaded", function(event) {
#         const breadcrumbContainer = document.querySelector(".seo-breadcrumbs-container");
#         if (breadcrumbContainer) {
#             const breadcrumbNavElm = breadcrumbContainer.querySelector("nav");
#             if(breadcrumbNavElm) {
#                 breadcrumbNavElm.scrollLeft = 2000;
#             }
#         }
#     });
# </script></div></div><div class="vim x-social-share" data-testid="x-social-share" id="x-social-share"><div data-social-entry="social-share-dweb"><div class="social-share"><div class="trigger-container"><!--F#2--><button class="fake-link fake-link--action" data-testid="ux-action" data-vi-tracking='{"eventFamily":"SOCSHARE","eventAction":"ACTN","actionKind":"CLICK","operationId":"2047675","flushImmediately":false,"eventProperty":{"sid":"p2047675.m123689.l127365"}}'><!--F#13--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans">Share</span><!--F/--><!--F/--><!--F/--></button><!--F/--></div></div></div></div><div class="vim d-watchlist-link" data-testid="d-watchlist-link"><div class="ux-section-module" data-testid="ux-section-module"><!--F#1--><div class="ux-section" data-testid="ux-section"><!--F#2--><div class="ux-section__content" data-testid="ux-section-content"><div class="ux-section__item"><!--F#0--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans ux-textspans--BOLD ux-textspans--EMPHASIS">|</span><!--F/--><!--F/--><!--F/--></div><div class="ux-section__item"><a data-clientpresentationmetadata='{"isWatching":"false","noFollow":"true","moduleKey":"ADD_TO_WATCHLIST","isMsku":"true"}' data-testid="ux-action" data-vi-tracking='{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"4429486","flushImmediately":false,"eventProperty":{"parentrq":"15b211bd18c0a7697751397affee2058","pageci":"7d02e09a-a7d2-49a4-8661-d8bb2541c2a7","moduledtl":"mi:2548|li:9113","sid":"p4429486.m2548.l9113"}}' href="https://www.ebay.com/myb/WatchListAdd?item=134638042371&amp;rt=nc&amp;sourcePage=4340&amp;tagId=-99&amp;var=434175605789&amp;SubmitAction.AddToListVI=x&amp;ssPageName=VIP%3Awatchlink%3Atop%3Aen&amp;_trksid=p4429486.m2548.l1359&amp;etn=Watch+list" rel="nofollow"><!--F#11--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans ux-textspans--PSEUDOLINK">Add to Watchlist</span><!--F/--><!--F/--><!--F/--></a></div></div><!--F/--> </div><!--F/--></div></div></div></div></div><div class="d-vi-main-container__top-panel"><div class="vim x-atf-top-river" data-testid="x-atf-top-river"><div class="vim d-vi-region" data-testid="d-vi-region"><div class="x-ads-placements adp-vim vim x-ads-placements--100938" data-testid="x-ads-placements"><div id="placement100938"></div></div><div class="vim x-alert-module" data-testid="x-alert-module"></div><div class="vim x-merch-nori" data-testid="x-merch-nori"><div class="x-ads-placements adp-vim vim x-ads-placements--101224" data-testid="x-ads-placements"><div><!--F#p_1--><div id="placement101224"><!--F#2--><!--F#4--><div class="x-ads-skeleton" data-testid="x-ads-skeleton" role="progressbar"><div class="x-ads-skeleton__container"><div class="x-ads-skeleton__title"></div><div class="x-ads-skeleton__list-items"><div class="x-ads-skeleton__item-card"><div class="x-ads-skeleton__image"></div><div class="x-ads-skeleton__text-container"><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--md"></div><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--md"></div><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--sm"></div><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--lg"></div><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--sm"></div></div></div><div class="x-ads-skeleton__item-card"><div class="x-ads-skeleton__image"></div><div class="x-ads-skeleton__text-container"><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--md"></div><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--md"></div><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--sm"></div><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--lg"></div><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--sm"></div></div></div><div class="x-ads-skeleton__item-card"><div class="x-ads-skeleton__image"></div><div class="x-ads-skeleton__text-container"><div class="x-ads-skeleton__text-row x-ads-skeleton__text-row--md"></div><div class="x ...
#     if(window) {
#         //TODO: Remove picTimer after cutover
#         window.picTimer = 0;
#         window.firstImgLoadTime = 0;
#     }
# </script><div class="vim d-picture-panel" data-testid="d-picture-panel"><div class="vim d-picture-minview" data-testid="d-picture-minview"><div id="vi_main_img_fs"><div class="vim ux-thumb-image-carousel" data-testid="ux-thumb-image-carousel"><div class="ux-image-filmstrip vertical h-500" style="--gap: 8px; --image-width: 45px; --image-height: 45px; --items-per-slide: 8"><button aria-label="Previous image - Item images" class="btn-nav prev icon-btn" data-ebayui="" disabled="" type="button"><!--F#1--><svg aria-hidden="true" class="icon icon--chevron-left-24" focusable="false"><defs><symbol id="icon-chevron-left-24" viewbox="0 0 24 24"><path d="m6.293 11.292 8-8a1 1 0 1 1 1.414 1.415L8.414 12l7.293 7.293a1 1 0 1 1-1.414 1.414l-8-8a.996.996 0 0 1 0-1.415Z"></path></symbol></defs><use href="#icon-chevron-left-24"></use></svg><!--F/--></button><div class="ux-image-filmstrip-carousel"><button class="ux-image-filmstrip-carousel-item image-treatment image" data-idx="0" tabindex="-1"><img alt="Picture 1 of 8" loading="lazy" onerror="this.src='https://pics.ebaystatic.com/aw/pics/nextGenVit/imgNoImg.gif';" src="https://i.ebayimg.com/images/g/e90AAOSwXtplVNFb/s-l64.png"/></button><button class="ux-image-filmstrip-carousel-item image-treatment video" data-idx="1" tabindex="-1"><img alt="Video 1 of 1" loading="lazy" onerror="this.src='https://pics.ebaystatic.com/aw/pics/nextGenVit/imgNoImg.gif';" src="https://i.ebayimg.com/images/g/RPgAAOSwLcBieqIK/s-l64.jpg"/><svg aria-hidden="true" class="icon icon--play-64-colored" focusable="false"><defs><symbol id="icon-play-64-colored" viewbox="0 0 64 64"><circle cx="32" cy="32" fill="#fff" fill-opacity=".88" r="32"></circle><path d="m26.131 16.41 21.6 13.33a2.648 2.648 0 0 1 0 4.52l-21.6 13.33C24.333 48.7 22 47.425 22 45.33V18.67c0-2.094 2.333-3.37 4.131-2.26Z" fill="#191919"></path></symbol></defs><use href="#icon-play-64-colored"></use></svg></button><button class="ux-image-filmstrip-carousel-item image-treatment image" data-idx="2" tabindex="-1"><img alt="Picture 2 of 8" loading="lazy" onerror="this.src='https://pics.ebaystatic.com/aw/pics/nextGenVit/imgNoImg.gif';" src="https://i.ebayimg.com/images/g/Q0MAAOSwSiplVNFc/s-l64.png"/></button><button class="ux-image-filmstrip-carousel-item image-treatment image" data-idx="3" tabindex="-1"><img alt="Picture 3 of 8" loading="lazy" onerror="this.src='https://pics.ebaystatic.com/aw/pics/nextGenVit/imgNoImg.gif';" src="https://i.ebayimg.com/images/g/nLEAAOSw37RlVNFd/s-l64.png"/></button><button class="ux-image-filmstrip-carousel-item image-treatment image" data-idx="4" tabindex="-1"><img alt="Picture 4 of 8" loading="lazy" onerror="this.src='https://pics.ebaystatic.com/aw/pics/nextGenVit/imgNoImg.gif';" src="https://i.ebayimg.com/images/g/UCsAAOSwsallVNFe/s-l64.png"/></button><button class="ux-image-filmstrip-carousel-item image-treatment image" data-idx="5" tabindex="-1"><img alt="Picture 5 of 8" loading="lazy" onerror="this.src='https://pics.ebaystatic.com/aw/pics/nextGenVit/imgNoImg.gif';" src="https://i.ebayimg.com/images/g/yagAAOSwbI5lVNFf/s-l64.png"/></button><button class="ux-image-filmstrip-carousel-item image-treatment image" data-idx="6" tabindex="-1"><img alt="Picture 6 of 8" loading="lazy" onerror="this.src='https://pics.ebaystatic.com/aw/pics/nextGenVit/imgNoImg.gif';" src="https://i.ebayimg.com/images/g/18AAAOSwFqNlVNFg/s-l64.png"/></button><button aria-current="true" class="ux-image-filmstrip-carousel-item image-treatment active image" data-idx="7" tabindex="-1"><img alt="Picture 7 of 8" loading="lazy" onerror="this.src='https://pics.ebaystatic.com/aw/pics/nextGenVit/imgNoImg.gif';" src="https://i.ebayimg.com/images/g/AKMAAOSwe09lVNFW/s-l64.png"/></button><button class="ux-image-filmstrip-carousel-item image-treatment image" data-idx="8" tabindex="-1"><img alt="Picture 8 of 8" loading="lazy" onerror="this.src='https://pics.ebaystatic.com/aw/pics/nextGenVit/imgNoImg.gif';" src="https://i.ebayimg.com/images/g/3U0AAOSwYThlVNFX/s-l64.png"/></but ...
#         var image = document.createElement('img');
#         image.src = "https://i.ebayimg.com/images/g/e90AAOSwXtplVNFb/s-l500.png";
#         if (image.complete || image.readyState === 4) { // cached images
#           window.picTimer2 = window.picTimer2 || new Date().getTime();
#         } else {
#           image.onload = function() {
#             window.picTimer1 = window.picTimer1 || new Date().getTime();
#           };
#         }
#       </script><div class="ux-image-carousel-container"><h2 aria-live="polite" class="clipped">Picture 7 of 8</h2><div class="ux-image-carousel-buttons ux-image-carousel-buttons__center-left"><button aria-label="Previous image - Item images" class="btn-prev icon-btn" data-ebayui="" type="button"><!--F#1--><svg aria-hidden="true" class="icon icon--chevron-left-24" focusable="false"><use href="#icon-chevron-left-24"></use></svg><!--F/--></button></div><div aria-label='Opens image gallery dialog Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3" 8GB 256GB SSD - Picture 7 of 8' class="ux-image-carousel img-transition-medium" role="button" tabindex="0"><div class="ux-image-carousel-item image" data-idx="0"><div class="ux-image-magnify" data-testid="ux-image-magnify" style="width:500px;height:500px;"><div class="ux-image-magnify__container"><div class="ux-image-magnify__lens" data-testid="ux-image-magnify__lens" role="group" style="transform:translate(0px, 0px);width:0px;height:0px;"></div><img alt='Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3" 8GB 256GB SSD - Picture 1 of 8' class="ux-image-magnify__image--original" data-onload-src="https://i.ebayimg.com/images/g/e90AAOSwXtplVNFb/s-l1600.png" data-zoom-src="https://i.ebayimg.com/images/g/e90AAOSwXtplVNFb/s-l1600.png" fetchpriority="high" loading="eager" onload="if (window &amp;&amp; (window.firstImgLoadTime == 0)) {window.firstImgLoadTime = new Date().getTime();} " src="https://i.ebayimg.com/images/g/e90AAOSwXtplVNFb/s-l500.png" style="max-width:500px;max-height:500px;"/></div></div></div><div class="ux-image-carousel-item video" data-idx="1"><div class="ux-video--image"><img alt="Video 1 of 1" data-src="https://i.ebayimg.com/images/g/RPgAAOSwLcBieqIK/s-l1600.jpg"/><svg aria-hidden="true" class="icon icon--play-64-colored" focusable="false"><use href="#icon-play-64-colored"></use></svg></div></div><div class="ux-image-carousel-item image" data-idx="2"><img alt='Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3" 8GB 256GB SSD - Picture 2 of 8' class="img-scale-down" data-src="https://i.ebayimg.com/images/g/Q0MAAOSwSiplVNFc/s-l500.png"/></div><div class="ux-image-carousel-item image" data-idx="3"><img alt='Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3" 8GB 256GB SSD - Picture 3 of 8' class="img-scale-down" data-src="https://i.ebayimg.com/images/g/nLEAAOSw37RlVNFd/s-l500.png"/></div><div class="ux-image-carousel-item image" data-idx="4"><img alt='Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3" 8GB 256GB SSD - Picture 4 of 8' class="img-scale-down" data-src="https://i.ebayimg.com/images/g/UCsAAOSwsallVNFe/s-l500.png"/></div><div class="ux-image-carousel-item image" data-idx="5"><img alt='Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3" 8GB 256GB SSD - Picture 5 of 8' class="img-scale-down" data-src="https://i.ebayimg.com/images/g/yagAAOSwbI5lVNFf/s-l500.png"/></div><div class="ux-image-carousel-item image" data-idx="6"><img alt='Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3" 8GB 256GB SSD - Picture 6 of 8' class="img-scale-down" data-src="https://i.ebayimg.com/images/g/18AAAOSwFqNlVNFg/s-l500.png"/></div><div class="ux-image-carousel-item active image" data-idx="7"><img alt='Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3" 8GB 256GB SSD - Picture 7 of 8' class="img-scale-down" data-src="https://i.ebayimg.com/images/g/AKMAAOSwe09lVNFW/s-l500.png"/></div><div class="ux-image-carousel-item image" data-idx="8"><img alt='Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3" 8GB 256GB SSD - Picture 8 of 8' class="img-scale-down" data-src="https://i.ebayimg.com/images/g/3U0AAOSwYThlVNFX/s-l500.png"/></div></div><div class="ux-image-carousel-buttons ux-image-carousel-buttons__center-right"><button aria-label="Next image - Item images" class="btn-next icon-btn" data-ebayui="" type="button"><!--F#1--><svg aria-hidden="true" class="icon icon--chev ...
#     self.onmessage = e => {
#         const request = e.data;
#         if(request && request.type && request.type == "request"){
#             doAjaxCall(request);
#         }
#     };
#
#     function doAjaxCall(request){
#         const xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = () => {
#             if (xhttp.readyState == 4) {
#                 xhttp.ontimeout = null;
#                 let responseObj = {};
#                 responseObj.type = 'response';
#                 responseObj.status = xhttp.status;
#
#                 if(xhttp.responseType == 'json'){
#                     responseObj.response = xhttp.response;
#                 }else{
#                     responseObj.responseText = xhttp.responseText;
#                 }
#                 self.postMessage(responseObj);
#             }
#         };
#         xhttp.open("GET", request.url, true);
#         xhttp.responseType = request.responseType;
#         xhttp.send('');
#         xhttp.timeout = request.timeout;
#         xhttp.ontimeout = e => {
#             xhttp.onreadystatechange = null;
#             self.postMessage({'type':'error', 'status':'timeout'});
#         };
#     }
# </script><div class="vim clearfix"></div><div class="vim x-msku" data-testid="x-msku"><div class="x-msku__box-cont"><label class="x-msku__label" for="x-msku__select-box-1000"><span class="x-msku__label-text"><span>Color</span></span><span class="x-msku__select-box-wrapper"><!--F#12[0]--><select aria-label="Please select a Color" autocomplete="off" class="x-msku__select-box" id="x-msku__select-box-1000" selectboxid="1000" selectboxlabel="Color"><option value="-1">- Select -</option><option id="x-msku__option-box-0" selected="selected" value="0"> Space Gray </option><option id="x-msku__option-box-1" value="1"> Silver </option></select><!--F/--><div aria-live="polite" class="x-msku__error" id="x-msku__select-box-1000-error"></div></span></label><span aria-hidden="true" class="x-msku__span"></span></div></div><div class="vim d-quantity" data-testid="d-quantity"><label class="d-quantity__label" for="qtyTextBox"><!--F#0--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans">Quantity:</span><!--F/--><!--F/--><!--F/--></label><div class="d-quantity__value"><div class="d-quantity__wrapper"><!--F#0--><span class="textbox d-quantity__input"><input aria-describedby="qtyErrMsg" autocomplete="off" class="textbox__control" disabled="" id="qtyTextBox" name="quantity" size="4" type="text" value="1"/></span><!--F/--></div></div><div class="d-quantity__availability"><div><!--F#0--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans">Limited quantity available</span><!--F/--><!--F#1[1]--><span class="ux-textspans"> / </span><!--F/--><!--F#1[2]--><span class="ux-textspans">967 sold</span><!--F/--><!--F/--><!--F/--></div></div></div></div><div class="vim d-vi-region x-atf-center-river--buybox" data-testid="d-vi-region"><div class="vim x-buybox" data-testid="x-buybox"><div class="x-buybox__section"><div class="x-buybox__price-section"><div class="vim x-bin-price" data-testid="x-bin-price"><div class="x-label" data-testid="x-label"><!--F#0--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans">Price:</span><!--F/--><!--F/--><!--F/--></div><div class="x-bin-price__content"><div class="x-price-primary" data-testid="x-price-primary"><!--F#0--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans">US $859.00</span><!--F/--><!--F/--><!--F/--></div><div class="x-additional-info" data-testid="x-additional-info"><div><!--F#0--><span class="x-additional-info__textual-display" data-testid="ux-textual-display"><!--F#1[0]--><span class="ux-textspans ux-textspans--SECONDARY">(US $627.01 / oz)</span><!--F/--></span><!--F/--></div><div><!--F#0--><span class="x-additional-info__textual-display" data-testid="ux-textual-display"><!--F#1[0]--><span class="ux-textspans">List price </span><!--F/--><!--F#1[1]--><span class="ux-textspans ux-textspans--STRIKETHROUGH">US $1,329.00</span><!--F/--><!--F#1[2]--><span class="ux-textspans"> </span><!--F/--></span><!--F/--><span class="ux-bubble-help" data-testid="ux-bubble-help"><span><span><!--F#0--><span class="infotip" data-vi-tracking='{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"4429486","flushImmediately":false,"eventProperty":{"parentrq":"15b211bd18c0a7697751397affee2058","pageci":"7d02e09a-a7d2-49a4-8661-d8bb2541c2a7","moduledtl":"mi:145235|li:3124","sid":"p4429486.m145235.l3124"}}' module-key="BUY_BOX"><button aria-label="What does this price mean?" class="infotip__host icon-btn icon-btn--transparent" type="button"><svg aria-hidden="true" class="icon icon--information-16" focusable="false"><defs><symbol id="icon-information-16" viewbox="0 0 16 16"><path d="M8 7a1 1 0 0 0-1 1v3a1 1 0 1 0 2 0V8a1 1 0 0 0-1-1Zm1-2a1 1 0 1 1-2 0 1 1 0 0 1 2 0Z"></path><path d="M0 8a8 8 0 1 1 16 0A8 8 0 0 1 0 8Zm2 0a6 6 0 1 0 12 0A6 6 0 0 0 2 8Z"></path></symbol></defs><use href="#icon-information-16"></use></svg></button><span class="infotip__overlay" id="s0-1-22-5-9-2-43[0]-3[0]-8-3[1]-1-ux-infotip-overlay" style="transform:translateX(16px) translateY(-50%) scale3d(1,1,1);left:100%;right:auto;top:-6px;bottom:auto; ...
# Was in a factory sealed box.
# Booted up quickly, needed full charge though.
# Now it is updating to the latest MacOS
# Thank You</span><!--F/--><!--F/--></div></div></div><div class="fdbk-container__details__item-link"><a _sp="p4429486.m41214.l155433" href="https://www.ebay.com/itm/166206685749" target="_blank"><!--F#4--><!--F#4--><span class="INLINE_LINK">Apple Macbook Air MLY33LL/A 2022 13.6" 8CPU/8GPU Apple M2 Chip 8GB/256GB SSD (#166206685749)</span><!--F/--><!--F/--></a></div></div></div><div class="fdbk-container" data-testid="tabbed-feedback-cards-2"><div class="fdbk-container__details"><div class="fdbk-container__details__top"><div class="fdbk-container__details__top__text"><div class="fdbk-container__details__info"><div class="fdbk-container__details__info__icon"><svg aria-label="Positive feedback rating" class="imagePosition icon icon--feedback-positive" data-test-id="shared-feedback-component-POSITIVE" data-test-type="positive" height="16" role="img" viewbox="0 0 16 16" width="16"><circle cx="8" cy="8" fill="#05823F" r="8"></circle><path d="M12.2857 7.28571H8.71429V3.71429C8.71429 3.3198 8.39449 3 8 3C7.60551 3 7.28571 3.3198 7.28571 3.71429V7.28571H3.71429C3.3198 7.28571 3 7.60551 3 8C3 8.39449 3.3198 8.71429 3.71429 8.71429H7.28571V12.2857C7.28571 12.6802 7.60551 13 8 13C8.39449 13 8.71429 12.6802 8.71429 12.2857V8.71429H12.2857C12.6802 8.71429 13 8.39449 13 8C13 7.60551 12.6802 7.28571 12.2857 7.28571Z" fill="white"></path></svg></div><div class="fdbk-container__details__info__username"><!--F#3--><!--F#4--><span>i***e (149)</span><!--F/--><span class="fb-clipped">- Feedback left by buyer i***e (149).</span><!--F/--></div><ul class="fdbk-container__details__info__divide"><li><span class="fdbk-container__details__info__divide__time"><!--F#3--><!--F#4--><span>Past month</span><!--F/--><!--F/--></span></li></ul></div><div class="fdbk-container__details__comment"><!--F#3--><!--F#4--><span>Item as described. Fast shipping! Great prices! </span><!--F/--><!--F/--></div></div></div><div class="fdbk-container__details__item-link"><a _sp="p4429486.m41214.l155433" href="https://www.ebay.com/itm/134342110536" target="_blank"><!--F#4--><!--F#4--><span class="INLINE_LINK">Nintendo Switch Lite 32GB Console - New (#134342110536)</span><!--F/--><!--F/--></a></div></div></div><a class="fdbk-detail-list__tabbed-btn fake-btn fake-btn--large fake-btn--secondary" data-ebayui="" data-track='{"eventFamily":"ITM","eventAction":"ACTN","actionKind":"CLICK","operationId":"4429486","flushImmediately":false,"eventProperty":{"moduledtl":"86322","sid":"p4429486.m86322.l148002"}}' href="https://www.ebay.com/fdbk/feedback_profile/guaranteecellular?filter=feedback_page%3ARECEIVED_AS_SELLER&amp;sort=TIME"><!--F#7-->See all feedback<!--F/--></a><!--F/--></div></div></div></div></div></div> <!--F/--></div></div></div></div> <div class="vim d-sme-btf" data-testid="d-sme-btf"></div><div id="placement_html_101112"></div><div id="placement_html_101110"></div><div id="placement_html_101111"></div><div id="placement_html_101113"></div><div id="placement_html_101506"></div><div class="x-ads-placements adp-vim vim x-ads-placements--100565" data-testid="x-ads-placements"><div id="placement100565"></div></div><div aria-label="Quick Links" class="vim d-pagenavigation-btf" data-testid="d-pagenavigation-btf" role="navigation"><!--F#0--><!--F#f_1--><a data-testid="ux-action" href="https://www.ebay.com"><!--F#13--><span class="ux-textspans">Back to home page</span><!--F/--></a><!--F/--><!--F/--><a data-testid="ux-action" href="#"><!--F#13--><!--F#f_1--><!--F#1[0]--><span class="ux-textspans">Return to top</span><!--F/--><!--F/--><!--F/--></a></div><div class="vim ux-navigator seo-interlink" data-testid="ux-navigator-seo-interlink" data-vi-scrolltracking='{"eventFamily":"ITM","eventAction":"VIEW","operationId":"4429486","flushImmediately":false,"eventProperty":{"moduledtl":"mi:2547"}}'><div class="ux-navigator__container"><div class="section-title ux-navigator__parent-title"><div class="section-title__title-container"><h2 class="section-title__title" id="s0-1-22-5-15-1-6[9]-0-4[0]-ti ...
# <div id="widget-platform">
# <script type="application/javascript">window.widget_platform = {"renderType":1,"renderDelay":500,"triggerFallBack":true,"status":4,"queryParam":null,"widgets":[{"html":"","css":null,"js":null,"jsInline":null,"init":""}],"showdiag":[]};</script>
# <div id="gh_user" style="display:none;"></div>
# </div>
# <!--[if lt IE 9]><div id="glbfooter" role="contentinfo" class="gh-w gh-flex"><![endif]--><footer class="gh-w gh-flex" id="glbfooter" role="contentinfo"><div><div id="rtm_html_1650"></div><div id="rtm_html_1651"></div></div><h2 class="gh-ar-hdn">Additional site navigation</h2><div id="gf-t-box"><table class="gf-t" role="presentation"><tr><td colspan="2"><ul class="gh-hide-if-nocss" id="gf-l"><li class="gf-li"><a _exsp="m571.l2602" class="thrd gf-bar-a" href="https://www.ebayinc.com/company">About eBay</a></li><li class="gf-li"><a _exsp="m571.l2935" class="thrd gf-bar-a" href="https://community.ebay.com/t5/Announcements/bg-p/Announcements">Announcements</a></li><li class="gf-li"><a _exsp="m571.l1540" class="thrd gf-bar-a" href="https://community.ebay.com">Community</a></li><li class="gf-li"><a _exsp="m571.l2616" class="thrd gf-bar-a" href="https://pages.ebay.com/securitycenter/index.html">Security Center</a></li><li class="gf-li"><a _exsp="m571.l1613" class="thrd gf-bar-a" href="https://pages.ebay.com/seller-center/index.html">Seller Information Center</a></li><li class="gf-li"><a _exsp="m571.l2604" class="thrd gf-bar-a" href="https://www.ebay.com/help/policies/default/ebays-rules-policies?id=4205">Policies</a></li><li class="gf-li"><a _exsp="m571.l3947" class="thrd gf-bar-a" href="https://partnernetwork.ebay.com">Affiliates</a></li><li class="gf-li"><a _sp="m571.l1545" class="thrd gf-bar-a" data-sp="m571.l1545" href="https://www.ebay.com/help/home">Help &amp; Contact</a></li><li class="gf-li"><a _exsp="m571.l2909" class="thrd gf-bar-a" href="https://pages.ebay.com/sitemap.html">Site Map</a></li></ul></td></tr><tr valign="top"><td class="gf-legal">Copyright © 1995-2023 eBay Inc. All Rights Reserved. <a href="https://www.ebayinc.com/accessibility/">Accessibility</a>, <a href="https://www.ebay.com/help/policies/member-behaviour-policies/user-agreement?id=4259">User Agreement</a>, <a href="https://www.ebay.com/help/policies/member-behaviour-policies/user-privacy-notice-privacy-policy?id=4260">Privacy</a>, <a href="https://pages.ebay.com/payment/2.0/terms.html">Payments Terms of Use</a>, <a href="https://www.ebay.com/help/policies/member-behaviour-policies/ebay-cookie-notice?id=4267">Cookies</a>, <a class="gf-legal__privacy" href="https://www.ebay.com/adchoice/ccpa">Your Privacy Choices</a> and <a href="https://www.ebay.com/adchoice" id="gf-AdChoice">AdChoice</a></td><td align="center" nowrap=""></td></tr></table></div><div class="adBanner" id="gh-bulletin-det" style="height:1px"></div><script type="text/javascript">
# 	(function(win){
# 		win.GH_ABD = {};
# 		win.GH_ABD.cfg = {"ckbit":82,"externalJsUrl":"https://secureir.ebaystatic.com/cr/v/c1/gh_show_ads.js"};
# 		var abElement = document.getElementById("gh-bulletin-det");
# 		if(abElement && win.getComputedStyle && typeof(win.getComputedStyle) === 'function'){
# 			var styleMap = win.getComputedStyle(abElement);
# 			if(styleMap['display'] === 'none' || abElement.offsetHeight<1){
# 				win.GH_ABD.bannerCollapsed = true;
# 				win.GH_ABD.detectionCompleted = true;
# 			}else{
# 				win.GH_ABD.bannerCollapsed = false;
# 				if(win.GH_ABD.cfg && win.GH_ABD.cfg.externalJsUrl){
# 					var scriptEl = document.createElement('script');
# 					scriptEl.onload = function(){
# 						win.GH_ABD.externaJs = true;
# 						win.GH_ABD.detectionCompleted = true;
# 					};
# 					scriptEl.onerror = function(){
# 						win.GH_ABD.externaJs = false;
# 						win.GH_ABD.detectionCompleted = true;
# 					};
# 					scriptEl.src = win.GH_ABD.cfg.externalJsUrl;
# 					scriptEl.defer = true;
# 					document.body.appendChild(scriptEl);
# 				}
# 			}
# 		}
# 	})(window);
# </script><!--[if lt IE 9]></div><![endif]--></footer><div class="vim x-footer-river" data-testid="x-footer-river"><div class="vim d-vi-region" data-testid="d-vi-region"><div class="x-ads-placements adp-vim vim x-ads-placements--100916" data-testid="x-ads-placements"><!--M#s0-1-28-10-1-94[0]-1--><div id="placement100916"></div><!--M/--></div><div class="x-ads-placements adp-vim vim x-ads-placements--100917" data-testid="x-ads-placements"><!--M#s0-1-28-10-1-94[1]-1--><div id="placement100917"></div><!--M/--></div><div class="x-ads-placements adp-vim vim x-ads-placements--100918" data-testid="x-ads-placements"><!--M#s0-1-28-10-1-94[2]-1--><div id="placement100918"></div><!--M/--></div></div></div><div class="vim x-seo-structured-data" data-testid="x-seo-structured-data"><script type="application/ld+json">
#             {"@type":"Product","@context":"https://schema.org","name":"Apple MacBook Pro Mneh3ll/a 2022 Apple M2 Chip   10GPU/8CPU 13.3&#034; 8GB 256GB SSD","image":"https://i.ebayimg.com/images/g/e90AAOSwXtplVNFb/s-l1600.png","offers":{"@type":"Offer","url":"https://www.ebay.com/itm/134638042371?_trkparms=pageci%3Acd839362-65cc-11ee-97da-8aa74efc965f%7Cparentrq%3A0f052b2b18b0acf322cec22dfffed4fc%7Ciid%3A1&var=434175605789","itemCondition":"https://schema.org/RefurbishedCondition","availability":"https://schema.org/InStock","priceCurrency":"USD","price":"859.0","shippingDetails":{"@type":"OfferShippingDetails","shippingRate":{"@type":"MonetaryAmount","value":"107.54","currency":"USD"}}},"mpn":"N/A","model":"MacBook Pro","brand":{"@type":"Brand","name":"Apple"}}
#         </script></div></footer></div><script src="https://ir.ebaystatic.com/rs/c/jquery-3.5.1.min.js"></script><script type="text/javascript">
#         var trackableCtas = ['BID','BIN','OFFER','WATCH','ATC'];
#         function trackableButtonsForUnload() {
#             var ctas = [];
#             document.querySelectorAll('.ux-call-to-action[data-track-disabled]').forEach(function(btn) {
#                 if (btn) {
#                     var cta = btn.getAttribute('data-track-disabled');
#                     if (cta && trackableCtas && trackableCtas.includes(cta)) {
#                         ctas.push(cta);
#                     }
#                 }
#             });
#             if (ctas && ctas.length > 0) {
#                 var uep = {
#                     'ctas': ctas.toString()
#                 };
#                 triggerCustomPulsar('158018', uep);
#             }
#         }
#
#         function triggerCustomPulsar(moduleId, uep) {
#             var trackData = {'eventFamily':'ITM','eventAction':'VIEW','operationId':'4429486','flushImmediately': false,'eventProperty':{'item': 134638042371,'moduledtl':`mi:${moduleId}`}};
#             var ep = Object.assign({}, uep, trackData.eventProperty);
#             trackData.eventProperty = ep;
#             $(document).trigger('pulsar', trackData);
#         }
#
#         window.addEventListener('beforeunload', function() {
#             try {
#                 trackableButtonsForUnload();
#             } catch(e){}
#         });
#
#         function handleDisabledCTATracking(e) {
#             var btn = e && e.target && e.target.querySelector('.ux-call-to-action');
#             var cta = btn && btn.getAttribute('data-track-disabled');
#             if (cta && trackableCtas && trackableCtas.includes(cta)) {
#                 triggerCustomPulsar('158338', {'ctas':cta});
#             }
#         }
#
#         window.addEventListener('load', function(event) {
#             document.querySelectorAll('.ux-call-to-action[data-track-disabled]').forEach(function(btn) {
#                 if (btn && btn.parentElement) {
#                     btn.parentElement.addEventListener('click', handleDisabledCTATracking);
#                 }
#             });
#         });
#     </script><script src="https://ir.ebaystatic.com/rs/c/inception-WgMT-42n.js"></script>
# <script src="https://ir.ebaystatic.com/rs/c/item-index-LwCf0Yet.js"></script>
# <script>$_mod.ready();</script><script src="https://ir.ebaystatic.com/rs/v/1n4fgejpwq10fp2xadwzpablca1.js" type="text/javascript"></script><script type="text/javascript"> (function(){ if(typeof(GH) !== 'undefined' && typeof(GH.add ) === 'function' ){ GH.add("GHModal__INIT_DATA", { ajaxURL: "/gh/shipto?modules=SHIP_TO_LOCATION", clickTriggerId: "gh-shipto-click", fetchMaxTimeOut: 6000, modalTitleId: "gh-shipto-label" }); } })(); (function(){ if(typeof(GH) !== 'undefined' && typeof(GH.add ) === 'function' ){ GH.add("GHShipTo__INIT_DATA", { clickTriggerId: "gh-shipto-click" }); } })(); (function($){ if(typeof(GHFlyout) === 'function') { new GHFlyout("/gh/watchlist?modules=WATCH_LIST", "gh-wl-click", ""); } })(GH && GH.jQ); (function($){ if(typeof(GHFlyout) === 'function') { new GHFlyout("/gh/cart?modules=MINI_CART", "", "gh-minicart-hover"); } })(GH && GH.jQ); if(typeof GH!="undefined"&&GH){GH.urls={ autocomplete_js:0,fnet_js:"https://c.paypal.com/da/r/efbv3.js",ie8_js:"https://ir.ebaystatic.com/f/rbezfuzpu20wfd2kvejeb5adxyg.js",scandal_js:"https://ir.ebaystatic.com/cr/v/c1/ScandalJS-1.2.0-v4.min.js",widget_delivery_platform:"https://ir.ebaystatic.com/cr/v/c1/globalheader_widget_platform__v2-b70676194b.js",auto_tracking_widget:"https://ir.ebaystatic.com/cr/v/c01/fa01a821-a934-4ec6-badc-90585489f1a0.min.js",web_resource_tracker:"https://ir.ebaystatic.com/rs/v/mjgerh5fmy51nnbwjoml1g1juqs.js",behavior_js_collection:"https://ir.ebaystatic.com/cr/v/c01/aW5ob3VzZWpzMTY5Njk3NDQzODIxNw==-1.0.0.min.js" }; GH.GHSW={ raptor:0,sandbox:0,emp:0,ac1:0,ac2:0,ac3:0,ac4:0,ac5:0,ac6:0,hideMobile:"true",langSwitch:0,pool:0,ALERT_POPUPOFF:0,NEWALERT_POPUPOFF:0,newprofile:0,desktop_new_profile_service:"true",UNLOAD_Firefox:0,UNLOAD_Chrome:0,UNLOAD_IE:0,UNLOAD_Safari:0,ENABLE_HTTPS:"true",SEARCH_PROM:"true",MINICART:0,STICKY_HEADER:0 }; } if(typeof GH!="undefined" && GH){GH_config={"lng":"en-US","geoLang":"[]","suppressGeoUserUpdateInfo":"false","siteId":"900","xhrBaseUrl":"https://www.ebay.com","env":"production","risk_behavior_collection_interval":"15000",sin:0,pageId:2332490,geoul:'IN',langs:1,fn:"",id:""};GH.init();}</script> <script src="https://ir.ebaystatic.com/cr/v/c1/ebay-cookies/1.js"></script><script type="text/javascript">(function(scope) {var trackingInfo = {"X_EBAY_C_CORRELATION_SESSION":"si=15b211e818c0a769775ea17aff9b4cb0,c=1,trkp=pageci%3Acd839362-65cc-11ee-97da-8aa74efc965f%7Cparentrq%3A0f052b2b18b0acf322cec22dfffed4fc%7Ciid%3A1,operationId=4429486,trk-gflgs=wA**"};scope.trkCorrelationSessionInfo={};scope.trkCorrelationSessionInfo.getTrackingInfo=function(){return trackingInfo;};scope.trkCorrelationSessionInfo.getTrackingCorrelationSessionInfo=function(){return trackingInfo.X_EBAY_C_CORRELATION_SESSION};})(window)</script><script type="text/javascript">if(typeof raptor !== "undefined" && raptor.require){var Uri=raptor.require("ebay/legacy/utils/Uri");$uri=function(href){return new Uri(href);};window.raptor.extend(window.raptor, require("ebay/legacy/adaptor-utils"));}</script><script id="taasHeaderRes" src="https://ir.ebaystatic.com/cr/v/c01/10341xh50yz21mhhydueu4m5wad.js" type="text/javascript"></script><script id="taasContent" type="text/javascript">try {new window.TaaSTrackingCore({"psi":"AshIv5cc*","rover":{"imp":"/roverimp/0/0/9","clk":"/roverclk/0/0/9","uri":"https://rover.ebay.com"},"pid":"p4429486"});
# var _plsubtInp={"eventFamily":"DFLT","samplingRate":100, "pageLoadTime": new Date().getTime(), "pageId":4429486, "app":"Testapp", "disableImp":true};var _plsUBTTQ=[];var TaaSIdMapTrackerObj = new TaaSIdMapTracker();TaaSIdMapTrackerObj.roverService("https://rover.ebay.com/idmap/0?footer");} catch (err) { console && console.log && console.log(err); }</script><script id="taasFooterRes" src="https://ir.ebaystatic.com/rs/v/s0hteylevy4bpkd12dvkd4yi5ms.js" type="text/javascript"></script><!--M#s0-1-36--><!--M/--><script>/* ssgST: excluded from sampling */</script><!--M#s0-1-38--><script id="init-main" type="text/javascript"></script><!--M/--><script>(window.$ebay||($ebay = {})).tracking={pageId:'2332490',pageName:'vinode'};$MC=(window.$MC||[]).concat({"o":{"l":1,"g":{"pageTemplateEPValue":null,"enableDwebSSE":false,"enableCTADisableTracking":true,"pageMerchRequestId":"15b211bd18c0a7697751397affee2058","urlParams":{"_trkparms":"pageci:cd839362-65cc-11ee-97da-8aa74efc965f|parentrq:0f052b2b18b0acf322cec22dfffed4fc|iid:1","var":"434175605789","correlation":"si=15b211e818c0a769775ea17aff9b4cb0,c=1,trkp=pageci%3Acd839362-65cc-11ee-97da-8aa74efc965f%7Cparentrq%3A0f052b2b18b0acf322cec22dfffed4fc%7Ciid%3A1,operationId=4429486,trk-gflgs=wA**","SSRFallback":0},"enableSEOForVideos":false,"enableJquery":"https://ir.ebaystatic.com/rs/c/jquery-3.5.1.min.js","nodeEnvironment":"production","pageTemplateId":"ViewItem","layoutSize":1280,"txnLayers":{"isBOTxnLayerEnabled":true,"isBIDTxnLayerEnabled":true,"isSIOTxnLayerEnabled":true,"isATCTxnLayerEnabled":false,"isSkeletonTxnLayerEnabled":true},"isDwebNode":true,"isViEvo":false,"viAppUrlHeader":"http://www.ebay.com/itm/134638042371?_trkparms=pageci%3Acd839362-65cc-11ee-97da-8aa74efc965f%7Cparentrq%3A0f052b2b18b0acf322cec22dfffed4fc%7Ciid%3A1&var=434175605789","vasAssets":{"desktop_vas":{"js":["https://ir.ebaystatic.com/rs/c/vasfe/179.d633f074.js"],"css":["https://ir.ebaystatic.com/rs/c/vasfe/179.53827e22.css"],"jsMap":["https://ir.ebaystatic.com/rs/c/vasfe/179.d633f074.js.map"],"cssMap":["https://ir.ebaystatic.com/rs/c/vasfe/179.53827e22.css.map"],"jsNoMin":["https://ir.ebaystatic.com/rs/c/vasfe/179.dbe4b6f7.nomin.js"],"cssNoMin":["https://ir.ebaystatic.com/rs/c/vasfe/179.12be06cc.nomin.css"]},"mobile_vas":{"js":["https://ir.ebaystatic.com/rs/c/vasfe/179.f5a4788f.js"],"css":["https://ir.ebaystatic.com/rs/c/vasfe/179.b0bdf18b.css"],"jsMap":["https://ir.ebaystatic.com/rs/c/vasfe/179.f5a4788f.js.map"],"cssMap":["https://ir.ebaystatic.com/rs/c/vasfe/179.b0bdf18b.css.map"],"jsNoMin":["https://ir.ebaystatic.com/rs/c/vasfe/179.8d6a984c.nomin.js"],"cssNoMin":["https://ir.ebaystatic.com/rs/c/vasfe/179.b9c0c867.nomin.css"]}},"isTouchEnabled":false,"isVerticalImageStripEnabled":true,"rlogid":"t6q4pnmjbb70%3C%3Dqkiu2soilac36(2matn*w%60ut3550-18c15b211bc-0x405","marketplaceId":"EBAY-US","userId":null,"country":"IN","language":"en","locale":"en-US","csrfTokenList":{"myebayweb":{"WatchListAdd":"0100080000005035a3f2827d7e7135dd6147999e45810eb55d54675641489292b78708655d677a81cb88fcd9c41111da45a4e53e8d5257fe1862c9efe49f884b9287d0faa95f240d6f90a39f7bffdd991da113c75da1d4","WatchListAddAjax":"01000800000050eb2156dfa9ecee80bf0cfa0558921d8cb35d84573c6ea21cf4895632806c78d80b011d62eb0f791594574b452d5c44361c452ae444c48e776f68c3f21820dc131d2d58ac4a2eedf47c3446e8a77c4a24","WatchListDelete":"01000800000050771e304850f1fd22de4b6d8b5963513848bccd5177d1cfb0884611186ecec917bfea9f1c904d965446ab949f017ce6a13078432a24d778b23145a56761800c105ae5063c01c074bc8b4b98b5093a0121"},"myebaynode":{"MyEbayNode_AjaxHandler":"0100080000005032817233b90944f201f4d9d1a9963d98aff406c1eadd9fd23e20b2130a98410b767c1995878a6e0b7ff38dc797b49e66733a5bd5ab1a26c151f0494b68c71ffcd825073f12e3b566e6e2b6ae5d22b082"},"cartfe":{"view_cartfe":"01000800000050549b7bc32063b3ad2d4469dc46dc1a9b0f4a615ce655cab9a553429dca992ffb7d472302f219b5d7de271d43af3df2600b89c7685a44b1a9453d7be51717b5429a5af0b820a3cbc76708407d07c26e83"},"nodeserv":{"customize":"010008000000509cd21088972686cf68 ...

# %%
name = soup_data.find("h1",{"class":"x-item-title__mainTitle"}).text.replace('"',"")[0:18].strip()

# %%
price = float(soup_data.find("div",{"class":"x-price-primary"}).text.strip("US $"))

# %%
name
# Out:
# 'Apple MacBook Pro'

# %%
price
# Out:
# 859.0

# %%
# connect with data  base (my sql connector)

# %%
pip install mysql_connector_python
# Out:
# Requirement already satisfied: mysql_connector_python in c:\users\shkum\lib\site-packages (8.1.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in c:\users\shkum\lib\site-packages (from mysql_connector_python) (4.21.12)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector as mcon

# %%
db=mcon.connect(host="localhost",user="root",password="Shashank@098")

# %%
cursor = db.cursor() # create a cursor object

# %%
cursor.execute("create database if not exists automation")

# %%
cursor.execute("use automation")

# %%
cursor.execute("create table if not exists macbook (date datetime,product_name varchar(255),price float)")

# %%
cursor.execute(f"insert into macbook values(current_timestamp(),'{name}',{price})")

# %%
db.commit()

# %%
db.close()

# %%
import streamlit as st

# %%
pip install plotly.express
# Out:
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\shkum\lib\site-packages (from plotly.express) (2.0.1)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\shkum\lib\site-packages (from plotly.express) (5.17.0)
# Collecting statsmodels>=0.9.0 (from plotly.express)
#   Downloading statsmodels-0.14.0-cp310-cp310-win_amd64.whl (9.2 MB)
#                                               0.0/9.2 MB ? eta -:--:--
#                                               0.2/9.2 MB 3.9 MB/s eta 0:00:03
#      ---                                      0.8/9.2 MB 8.7 MB/s eta 0:00:01
#      ------                                   1.5/9.2 MB 10.8 MB/s eta 0:00:01
#      --------                                 1.9/9.2 MB 10.2 MB/s eta 0:00:01
#      ---------                                2.3/9.2 MB 9.7 MB/s eta 0:00:01
#      -----------                              2.6/9.2 MB 9.2 MB/s eta 0:00:01
#      ---------------                          3.6/9.2 MB 10.8 MB/s eta 0:00:01
#      ------------------                       4.3/9.2 MB 11.6 MB/s eta 0:00:01
#      ----------------------                   5.2/9.2 MB 12.3 MB/s eta 0:00:01
#      --------------------------               6.1/9.2 MB 12.9 MB/s eta 0:00:01
#      ------------------------------           7.0/9.2 MB 13.1 MB/s eta 0:00:01
#      ---------------------------------        7.8/9.2 MB 13.4 MB/s eta 0:00:01
#      -------------------------------------    8.7/9.2 MB 13.8 MB/s eta 0:00:01
#      ---------------------------------------  9.2/9.2 MB 14.0 MB/s eta 0:00:01
#      ---------------------------------------- 9.2/9.2 MB 13.4 MB/s eta 0:00:00
# Collecting scipy>=0.18 (from plotly.express)
#   Downloading scipy-1.11.3-cp310-cp310-win_amd64.whl (44.1 MB)
#                                               0.0/44.1 MB ? eta -:--:--
#                                               0.3/44.1 MB 6.1 MB/s eta 0:00:08
#                                               0.9/44.1 MB 11.6 MB/s eta 0:00:04
#      -                                        1.6/44.1 MB 12.6 MB/s eta 0:00:04
#      -                                        1.9/44.1 MB 11.2 MB/s eta 0:00:04
#      -                                        2.1/44.1 MB 9.6 MB/s eta 0:00:05
#      -                                        2.1/44.1 MB 9.6 MB/s eta 0:00:05
#      --                                       2.9/44.1 MB 9.3 MB/s eta 0:00:05
#      --                                       3.3/44.1 MB 9.2 MB/s eta 0:00:05
#      --                                       3.3/44.1 MB 9.2 MB/s eta 0:00:05
#      ---                                      3.3/44.1 MB 7.1 MB/s eta 0:00:06
#      ---                                      3.4/44.1 MB 7.0 MB/s eta 0:00:06
#      ---                                      3.4/44.1 MB 7.0 MB/s eta 0:00:06
#      ---                                      3.4/44.1 MB 7.0 MB/s eta 0:00:06
#      ---                                      3.5/44.1 MB 5.6 MB/s eta 0:00:08
#      ---                                      3.5/44.1 MB 5.6 MB/s eta 0:00:08
#      ---                                      3.5/44.1 MB 5.6 MB/s eta 0:00:08
#      ---                                      3.6/44.1 MB 4.6 MB/s eta 0:00:09
#      ---                                      3.6/44.1 MB 4.5 MB/s eta 0:00:10
#      ---                                      3.6/44.1 MB 4.5 MB/s eta 0:00:10
#      ---                                      3.6/44.1 MB 4.5 MB/s eta 0:00:10
#      ---                                      3.6/44.1 MB 4.5 MB/s eta 0:00:10
#      ---                                      4.0/44.1 MB 3.8 MB/s eta 0:00:11
#      ---                                      4.0/44.1 MB 3.8 MB/s eta 0:00:11
#      ---                                      4.1/44.1 MB 3.7 MB/s eta 0:00:11
#      ---                                      4.3/44.1 MB 3.6 MB/s eta 0:00:12
#      ----                                     4.6/44.1 MB 3.7 MB/s eta 0:00:11
#      ----                                     4.9/44.1 MB 3.9 MB/s eta 0:00:11
#      ----                                     5.1/44.1 MB 3.9 MB/s eta 0:00:11
#      ----                                     5.5/44.1 MB 4.0 MB/s eta 0:00:10
#      -----                                    5.7/44.1 MB 4.1 MB/s eta 0:00:10
#      -----                                    5.9/44.1 MB 4.1 MB/s eta 0:00:10
#      -----                                    6.1/44.1 MB 4.1 MB/s eta 0:00:10
#      -----                                    6.2/44.1 MB 4.0 MB/s eta 0:00:10
#      -----                                    6.4/44.1 MB 4.0 MB/s eta 0:00:10
#      ------                                   7.0/44.1 MB 4.2 MB/s eta 0:00:09
#      ------                                   7.3/44.1 MB 4.3 MB/s eta 0:00:09
#      ------                                   7.3/44.1 MB 4.3 MB/s eta 0:00:09
#      ------                                   7.3/44.1 MB 4.3 MB/s eta 0:00:09
#      ------                                   7.3/44.1 MB 4.3 MB/s eta 0:00:09
#      ------                                   7.3/44.1 MB 4.3 MB/s eta 0:00:09
#      ------                                   7.3/44.1 MB 3.8 MB/s eta 0:00:10
#      ------                                   7.5/44.1 MB 3.8 MB/s eta 0:00:10
#      ------                                   7.5/44.1 MB 3.8 MB/s eta 0:00:10
#      ------                                   7.5/44.1 MB 3.8 MB/s eta 0:00:10
#      ------                                   7.6/44.1 MB 3.6 MB/s eta 0:00:11
#      -------                                  8.0/44.1 MB 3.7 MB/s eta 0:00:10
#      -------                                  8.2/44.1 MB 3.7 MB/s eta 0:00:10
#      -------                                  8.4/44.1 MB 3.7 MB/s eta 0:00:10
#      -------                                  8.5/44.1 MB 3.7 MB/s eta 0:00:10
#      --------                                 9.0/44.1 MB 3.8 MB/s eta 0:00:10
#      --------                                 9.0/44.1 MB 3.7 MB/s eta 0:00:10
#      --------                                 9.0/44.1 MB 3.7 MB/s eta 0:00:10
#      --------                                 9.2/44.1 MB 3.7 MB/s eta 0:00:10
#      --------                                 9.3/44.1 MB 3.7 MB/s eta 0:00:10
#      --------                                 9.9/44.1 MB 3.8 MB/s eta 0:00:10
#      ---------                                10.0/44.1 MB 3.8 MB/s eta 0:00:09
#      ---------                                10.2/44.1 MB 3.8 MB/s eta 0:00:09
#      ---------                                10.5/44.1 MB 3.8 MB/s eta 0:00:09
#      ---------                                10.6/44.1 MB 3.7 MB/s eta 0:00:10
#      ---------                                11.0/44.1 MB 3.7 MB/s eta 0:00:09
#      ----------                               11.1/44.1 MB 3.7 MB/s eta 0:00:10
#      ----------                               11.1/44.1 MB 3.6 MB/s eta 0:00:10
#      ----------                               11.2/44.1 MB 3.6 MB/s eta 0:00:10
#      ----------                               11.3/44.1 MB 3.5 MB/s eta 0:00:10
#      ----------                               11.3/44.1 MB 3.5 MB/s eta 0:00:10
#      ----------                               11.4/44.1 MB 3.4 MB/s eta 0:00:10
#      ----------                               11.4/44.1 MB 3.4 MB/s eta 0:00:10
#      ----------                               11.6/44.1 MB 3.3 MB/s eta 0:00:10
#      ----------                               11.7/44.1 MB 3.3 MB/s eta 0:00:10
#      ----------                               11.8/44.1 MB 3.2 MB/s eta 0:00:10
#      ----------                               12.0/44.1 MB 3.2 MB/s eta 0:00:11
#      -----------                              12.1/44.1 MB 3.2 MB/s eta 0:00:11
#      -----------                              12.2/44.1 MB 3.2 MB/s eta 0:00:11
#      -----------                              12.2/44.1 MB 3.2 MB/s eta 0:00:11
#      -----------                              12.2/44.1 MB 3.2 MB/s eta 0:00:11
#      -----------                              12.3/44.1 MB 3.1 MB/s eta 0:00:11
#      -----------                              12.3/44.1 MB 3.1 MB/s eta 0:00:11
#      -----------                              12.5/44.1 MB 3.0 MB/s eta 0:00:11
#      -----------                              12.6/44.1 MB 3.0 MB/s eta 0:00:11
#      -----------                              12.7/44.1 MB 2.9 MB/s eta 0:00:11
#      -----------                              12.7/44.1 MB 2.9 MB/s eta 0:00:11
#      -----------                              12.7/44.1 MB 2.9 MB/s eta 0:00:11
#      -----------                              12.7/44.1 MB 2.9 MB/s eta 0:00:11
#      -----------                              12.8/44.1 MB 2.8 MB/s eta 0:00:12
#      -----------                              12.8/44.1 MB 2.8 MB/s eta 0:00:12
#      -----------                              12.9/44.1 MB 2.7 MB/s eta 0:00:12
#      -----------                              13.0/44.1 MB 2.7 MB/s eta 0:00:12
#      ------------                             13.3/44.1 MB 2.7 MB/s eta 0:00:12
#      ------------                             13.5/44.1 MB 2.7 MB/s eta 0:00:12
#      ------------                             13.6/44.1 MB 2.7 MB/s eta 0:00:12
#      ------------                             13.9/44.1 MB 2.9 MB/s eta 0:00:11
#      ------------                             14.1/44.1 MB 3.1 MB/s eta 0:00:10
#      ------------                             14.1/44.1 MB 3.0 MB/s eta 0:00:10
#      ------------                             14.1/44.1 MB 3.0 MB/s eta 0:00:10
#      ------------                             14.3/44.1 MB 3.0 MB/s eta 0:00:10
#      ------------                             14.3/44.1 MB 3.0 MB/s eta 0:00:10
#      ------------                             14.3/44.1 MB 3.0 MB/s eta 0:00:10
#      -------------                            14.5/44.1 MB 2.9 MB/s eta 0:00:11
#      -------------                            14.6/44.1 MB 2.9 MB/s eta 0:00:11
#      -------------                            14.9/44.1 MB 2.9 MB/s eta 0:00:10
#      -------------                            15.2/44.1 MB 2.9 MB/s eta 0:00:10
#      --------------                           15.5/44.1 MB 2.9 MB/s eta 0:00:10
#      --------------                           15.9/44.1 MB 2.9 MB/s eta 0:00:10
#      --------------                           16.5/44.1 MB 3.1 MB/s eta 0:00:09
#      ---------------                          16.7/44.1 MB 3.1 MB/s eta 0:00:09
#      ---------------                          17.0/44.1 MB 3.0 MB/s eta 0:00:09
#      ---------------                          17.2/44.1 MB 3.0 MB/s eta 0:00:09
#      ---------------                          17.6/44.1 MB 3.2 MB/s eta 0:00:09
#      ----------------                         17.8/44.1 MB 3.4 MB/s eta 0:00:08
#      ----------------                         18.1/44.1 MB 3.4 MB/s eta 0:00:08
#      ----------------                         18.5/44.1 MB 3.4 MB/s eta 0:00:08
#      -----------------                        18.8/44.1 MB 3.4 MB/s eta 0:00:08
#      -----------------                        19.1/44.1 MB 3.4 MB/s eta 0:00:08
#      -----------------                        19.4/44.1 MB 3.6 MB/s eta 0:00:07
#      -----------------                        19.9/44.1 MB 3.6 MB/s eta 0:00:07
#      ------------------                       20.2/44.1 MB 3.6 MB/s eta 0:00:07
#      ------------------                       20.8/44.1 MB 3.7 MB/s eta 0:00:07
#      -------------------                      21.3/44.1 MB 3.9 MB/s eta 0:00:06
#      -------------------                      21.7/44.1 MB 4.2 MB/s eta 0:00:06
#      --------------------                     22.3/44.1 MB 4.5 MB/s eta 0:00:05
#      --------------------                     23.0/44.1 MB 6.2 MB/s eta 0:00:04
#      ---------------------                    23.4/44.1 MB 6.3 MB/s eta 0:00:04
#      ---------------------                    23.6/44.1 MB 6.4 MB/s eta 0:00:04
#      ---------------------                    23.7/44.1 MB 6.2 MB/s eta 0:00:04
#      ---------------------                    24.0/44.1 MB 6.4 MB/s eta 0:00:04
#      ---------------------                    24.2/44.1 MB 6.2 MB/s eta 0:00:04
#      ----------------------                   24.7/44.1 MB 7.4 MB/s eta 0:00:03
#      ----------------------                   24.8/44.1 MB 7.4 MB/s eta 0:00:03
#      ----------------------                   25.0/44.1 MB 7.4 MB/s eta 0:00:03
#      ----------------------                   25.2/44.1 MB 7.4 MB/s eta 0:00:03
#      -----------------------                  25.6/44.1 MB 7.4 MB/s eta 0:00:03
#      -----------------------                  26.3/44.1 MB 7.6 MB/s eta 0:00:03
#      ------------------------                 26.8/44.1 MB 7.6 MB/s eta 0:00:03
#      ------------------------                 27.0/44.1 MB 7.6 MB/s eta 0:00:03
#      -------------------------                27.7/44.1 MB 7.9 MB/s eta 0:00:03
#      -------------------------                28.3/44.1 MB 8.2 MB/s eta 0:00:02
#      --------------------------               29.2/44.1 MB 8.6 MB/s eta 0:00:02
#      ---------------------------              30.1/44.1 MB 9.2 MB/s eta 0:00:02
#      ---------------------------              30.3/44.1 MB 9.2 MB/s eta 0:00:02
#      ----------------------------             31.2/44.1 MB 9.2 MB/s eta 0:00:02
#      ----------------------------             31.2/44.1 MB 9.2 MB/s eta 0:00:02
#      ----------------------------             31.3/44.1 MB 8.6 MB/s eta 0:00:02
#      ----------------------------             31.4/44.1 MB 8.6 MB/s eta 0:00:02
#      ----------------------------             31.5/44.1 MB 8.2 MB/s eta 0:00:02
#      ----------------------------             31.7/44.1 MB 8.1 MB/s eta 0:00:02
#      -----------------------------            32.1/44.1 MB 8.1 MB/s eta 0:00:02
#      -----------------------------            32.6/44.1 MB 7.9 MB/s eta 0:00:02
#      ------------------------------           33.3/44.1 MB 8.0 MB/s eta 0:00:02
#      -------------------------------          34.3/44.1 MB 9.0 MB/s eta 0:00:02
#      -------------------------------          35.1/44.1 MB 9.9 MB/s eta 0:00:01
#      -------------------------------         35.7/44.1 MB 10.6 MB/s eta 0:00:01
#      -------------------------------         35.9/44.1 MB 10.1 MB/s eta 0:00:01
#      --------------------------------        36.9/44.1 MB 10.1 MB/s eta 0:00:01
#      ---------------------------------       37.5/44.1 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------       37.7/44.1 MB 10.2 MB/s eta 0:00:01
#      ---------------------------------       37.8/44.1 MB 10.2 MB/s eta 0:00:01
#      ----------------------------------       38.0/44.1 MB 9.6 MB/s eta 0:00:01
#      ----------------------------------       38.0/44.1 MB 9.6 MB/s eta 0:00:01
#      ----------------------------------       38.3/44.1 MB 9.1 MB/s eta 0:00:01
#      ----------------------------------       38.5/44.1 MB 8.8 MB/s eta 0:00:01
#      -----------------------------------      39.1/44.1 MB 8.6 MB/s eta 0:00:01
#      -----------------------------------      39.5/44.1 MB 8.6 MB/s eta 0:00:01
#      ------------------------------------     40.4/44.1 MB 8.7 MB/s eta 0:00:01
#      -------------------------------------    41.0/44.1 MB 8.7 MB/s eta 0:00:01
#      -------------------------------------    41.7/44.1 MB 9.9 MB/s eta 0:00:01
#      --------------------------------------  43.1/44.1 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------  43.8/44.1 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------  44.1/44.1 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------  44.1/44.1 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------  44.1/44.1 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------  44.1/44.1 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------  44.1/44.1 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------  44.1/44.1 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------  44.1/44.1 MB 10.9 MB/s eta 0:00:01
#      ---------------------------------------- 44.1/44.1 MB 8.0 MB/s eta 0:00:00
# Collecting patsy>=0.5 (from plotly.express)
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#                                               0.0/233.8 kB ? eta -:--:--
#      ------------------------------------- 233.8/233.8 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11 in c:\users\shkum\lib\site-packages (from plotly.express) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shkum\lib\site-packages (from pandas>=0.20.0->plotly.express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shkum\lib\site-packages (from pandas>=0.20.0->plotly.express) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shkum\lib\site-packages (from pandas>=0.20.0->plotly.express) (2023.3)
# Requirement already satisfied: six in c:\users\shkum\lib\site-packages (from patsy>=0.5->plotly.express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\shkum\lib\site-packages (from plotly>=4.1.0->plotly.express) (8.2.3)
# Requirement already satisfied: packaging in c:\users\shkum\lib\site-packages (from plotly>=4.1.0->plotly.express) (23.1)
# Installing collected packages: scipy, patsy, statsmodels, plotly.express
# Successfully installed patsy-0.5.3 plotly.express-0.4.1 scipy-1.11.3 statsmodels-0.14.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %%
pip install streamlit
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: streamlit in c:\users\shkum\lib\site-packages (1.27.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\shkum\lib\site-packages (from streamlit) (5.1.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\shkum\lib\site-packages (from streamlit) (1.6.3)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\shkum\lib\site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\shkum\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\shkum\lib\site-packages (from streamlit) (6.8.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\shkum\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\shkum\lib\site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\shkum\lib\site-packages (from streamlit) (2.0.1)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\shkum\lib\site-packages (from streamlit) (10.0.1)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\shkum\lib\site-packages (from streamlit) (4.21.12)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\shkum\lib\site-packages (from streamlit) (13.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\shkum\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\shkum\lib\site-packages (from streamlit) (2.30.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\shkum\lib\site-packages (from streamlit) (13.6.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\shkum\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\shkum\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\shkum\lib\site-packages (from streamlit) (4.8.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\shkum\lib\site-packages (from streamlit) (5.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\shkum\lib\site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\shkum\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\shkum\lib\site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\shkum\lib\site-packages (from streamlit) (6.3.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\shkum\lib\site-packages (from streamlit) (3.0.0)
# Requirement already satisfied: jinja2 in c:\users\shkum\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\shkum\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\shkum\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\shkum\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\shkum\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\shkum\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shkum\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shkum\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\shkum\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shkum\lib\site-packages (from requests<3,>=2.27->streamlit) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shkum\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shkum\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shkum\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shkum\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shkum\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\shkum\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shkum\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\shkum\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\shkum\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shkum\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart



# SENDING MAIL

# Outlook SMTP server and port
smtp_server = 'smtp-mail.outlook.com'
smtp_port = 587

# Your Outlook email address and password
email_address = 'shashanktheking1997@outlook.com'
email_password = 'Qwert@123qwert'

# Recipient's email address
recipient_email = 'shashanktheking1997@outlook.com'

# Create the email message
subject = 'Hello from Python'
message = 'This is a test email sent from Python using SMTP Outlook Server.'

msg = MIMEMultipart()
msg['From'] = email_address
msg['To'] = recipient_email
msg['Subject'] = subject
msg.attach(MIMEText(message, 'plain'))

# Establish an SMTP connection with Outlook
try:
    server = smtplib.SMTP(smtp_server, 587)
    server.starttls()
    server.login(email_address, email_password)
    server.sendmail(email_address, recipient_email, msg.as_string())
    server.quit()
    st.write("Email sent successfully.")
except Exception as e:
    st.write("Error: Could not send email.")
    st.write(e)

# %%
import smtplib

# %%
pip install smtplib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement smtplib (from versions: none)
# ERROR: No matching distribution found for smtplib
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import datetime
